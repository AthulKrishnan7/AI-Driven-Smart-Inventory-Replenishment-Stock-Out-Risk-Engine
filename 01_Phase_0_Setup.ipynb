# %% [markdown]
# ## Create Database

# %%
# %sql
Create database if not exists inventory_ai;
use inventory_ai;

# %%
# Define table prefixes for clarity
BRONZE_PREFIX = "bronze_"
SILVER_PREFIX = "silver_"
GOLD_PREFIX   = "gold_"

# %%
project_description = """
AI-Driven Smart Inventory Replenishment & Stock-Out Risk Engine

Tech Stack:
- Databricks Free Edition
- Delta Lake
- MLflow
- Medallion Architecture (Bronze / Silver / Gold)

Goal:
Predict demand, assess stock-out risk, and recommend optimal replenishment quantities.
"""

print(project_description)

# %% [markdown]
# Inventory Snapshot
